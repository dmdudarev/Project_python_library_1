# %%
import numpy as np
import pandas as pd
import random
import datetime
import math
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import seaborn as sns
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score as r2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def evaluate_preds(train_true_values, train_pred_values, test_true_values, test_pred_values):
    print("Train R2:\t" + str(round(r2(train_true_values, train_pred_values), 3)))
    print("Test R2:\t" + str(round(r2(test_true_values, test_pred_values), 3)))
    
    plt.figure(figsize=(18,10))
    
    plt.subplot(121)
    sns.scatterplot(x=train_pred_values, y=train_true_values)
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('Train sample prediction')
    
    plt.subplot(122)
    sns.scatterplot(x=test_pred_values, y=test_true_values)
    plt.xlabel('Predicted values')
    plt.ylabel('True values')
    plt.title('Test sample prediction')

    plt.show()

# %%
TRAIN_DATASET_PATH = 'train.csv'
TEST_DATASET_PATH = 'test.csv'
PREDICTIONS_PATH = 'Dmitriy_Dudarev_predictions.csv'

# %%
train_df = pd.read_csv(TRAIN_DATASET_PATH)

# %%
train_df.shape
# Out:
# (10000, 20)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
#  17  Shops_1        10000 non-null  int64
#  18  Shops_2        10000 non-null  object
#  19  Price          10000 non-null  float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %%
train_df['Id'] = train_df['Id'].astype(str)
train_df['DistrictId'] = train_df['DistrictId'].astype(str)

# %%
# если жилая плащадь больше общей, то приравниваем её к общей
m = train_df['Square'] < train_df['LifeSquare']
train_df.loc[m,'LifeSquare'] = train_df.loc[m,'Square'] 
# заполняем пропуски в значениях жилой площади значениями общей площади
m = train_df['LifeSquare'].isna()
train_df.loc[m,'LifeSquare'] = train_df.loc[m,'Square'] 
train_df.sort_values(by='Square')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7470  14786          1    1.0    1.136859    1.136859            1.0      3
# 4496  15744         34    1.0    1.988943    1.988943            1.0     21
# 9869   3224         27    0.0    2.377248    0.873147            0.0      1
# 8572  10202          6    1.0    2.596351    2.596351            1.0      3
# 161    6782         45    1.0    2.954309    2.954309            1.0      3
# ...     ...        ...    ...         ...         ...            ...    ...
# 7644   7917         27    0.0  212.932361  211.231125            0.0      2
# 1906   5548         86    5.0  275.645284  233.949309           26.0     12
# 7010   2307        102    1.0  409.425181  409.425181           10.0      4
# 726      28          9    2.0  604.705972  604.705972            1.0     17
# 9229  11602         30    2.0  641.065193  638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7470         1.0       1977   0.007122         B         B         1
# 4496         4.0       1977   0.069753         B         B        53
# 9869         0.0       1977   0.017647         B         B         2
# 8572        25.0       2014   0.243205         B         B         5
# 161          1.0       1977   0.195781         B         B        23
# ...          ...        ...        ...       ...       ...       ...
# 7644         3.0       2008   0.211401         B         B         9
# 1906        37.0       2011   0.161976         B         A        31
# 7010         4.0       2016   0.238617         B         B        26
# 726         18.0       1977   0.161532         B         B        25
# 9229        19.0       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 7470       264         0           NaN            0        1       B
# 4496     13670         4           NaN            1       11       B
# 9869       469         0           NaN            0        0       B
# 8572      1564         0         540.0            0        0       B
# 161       5212         6           NaN            3        2       B
# ...        ...       ...           ...          ...      ...     ...
# 7644      1892         0           NaN            0        1       B
# 1906      7010         5        4508.0            3        7       B
# 7010      3889         6         705.0            3        6       B
# 726       5648         1          30.0            2        4       B
# 9229      6398       141        1046.0            3       23       B
#
#               Price
# 7470  181434.825589
# 4496  458378.777006
# 9869  126596.941798
# 8572  137597.601458
# 161   438005.182323
# ...             ...
# 7644  302211.260887
# 1906  455264.882666
# 7010   90470.430830
# 726   187717.242538
# 9229  133529.681562
#
# [10000 rows x 20 columns]

# %%
Square_median = train_df['Square'].median()
Square_median
# Out:
# 52.51330992401352

# %%
# если общая площадь менее 15, заменяем на медиану
m = train_df['Square'] < 15
train_df.loc[m,'Square'] = Square_median 
train_df.sort_values(by='Square')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 5870   6927         21    1.0   16.117154    8.822988            0.0      2
# 3686  15877         57    3.0   16.547242   16.547242            8.0      5
# 9349  15127        150    1.0   17.046188   17.046188            8.0      7
# 8501  12927         62    2.0   17.414181   17.414181            1.0      4
# 6632  13685          0    1.0   17.498542   13.446544            0.0      7
# ...     ...        ...    ...         ...         ...            ...    ...
# 7644   7917         27    0.0  212.932361  211.231125            0.0      2
# 1906   5548         86    5.0  275.645284  233.949309           26.0     12
# 7010   2307        102    1.0  409.425181  409.425181           10.0      4
# 726      28          9    2.0  604.705972  604.705972            1.0     17
# 9229  11602         30    2.0  641.065193  638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 5870         5.0       1965   0.194489         B         B        47
# 3686         5.0       1962   0.133215         B         B        49
# 9349        12.0       1982   0.300323         B         B        52
# 8501        20.0       1977   0.072158         B         B         2
# 6632         5.0       1961   0.319809         B         B        25
# ...          ...        ...        ...       ...       ...       ...
# 7644         3.0       2008   0.211401         B         B         9
# 1906        37.0       2011   0.161976         B         A        31
# 7010         4.0       2016   0.238617         B         B        26
# 726         18.0       1977   0.161532         B         B        25
# 9229        19.0       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 5870      8004         3         125.0            3        5       B
# 3686     11395         3        1406.0            3        4       A
# 9349     10311         6           NaN            1        9       B
# 8501       629         1           NaN            0        0       A
# 6632      4756        16        2857.0            5        8       B
# ...        ...       ...           ...          ...      ...     ...
# 7644      1892         0           NaN            0        1       B
# 1906      7010         5        4508.0            3        7       B
# 7010      3889         6         705.0            3        6       B
# 726       5648         1          30.0            2        4       B
# 9229      6398       141        1046.0            3       23       B
#
#               Price
# 5870   79913.267856
# 3686   77835.185808
# 9349   74222.110465
# 8501  180750.471749
# 6632   88871.750230
# ...             ...
# 7644  302211.260887
# 1906  455264.882666
# 7010   90470.430830
# 726   187717.242538
# 9229  133529.681562
#
# [10000 rows x 20 columns]

# %%
# общая площадь более 300 - неверно поставленная запятая, делим на 10
m = train_df['Square'] > 300
train_df.loc[m,'Square'] = train_df.loc[m,'Square']/10 
train_df.sort_values(by='Square')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 5870   6927         21    1.0   16.117154    8.822988            0.0      2
# 3686  15877         57    3.0   16.547242   16.547242            8.0      5
# 9349  15127        150    1.0   17.046188   17.046188            8.0      7
# 8501  12927         62    2.0   17.414181   17.414181            1.0      4
# 6632  13685          0    1.0   17.498542   13.446544            0.0      7
# ...     ...        ...    ...         ...         ...            ...    ...
# 1606   3718         56    3.0  190.857689  107.376164           19.0      7
# 9307   4249         23    5.0  198.930182  123.139863           10.0      1
# 1776  16568         27    4.0  200.334539  200.334539           25.0      1
# 7644   7917         27    0.0  212.932361  211.231125            0.0      2
# 1906   5548         86    5.0  275.645284  233.949309           26.0     12
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 5870         5.0       1965   0.194489         B         B        47
# 3686         5.0       1962   0.133215         B         B        49
# 9349        12.0       1982   0.300323         B         B        52
# 8501        20.0       1977   0.072158         B         B         2
# 6632         5.0       1961   0.319809         B         B        25
# ...          ...        ...        ...       ...       ...       ...
# 1606         3.0       2007   0.000000         B         B        23
# 9307         2.0       2011   0.014073         B         B         2
# 1776         2.0       2013   0.041116         B         B        53
# 7644         3.0       2008   0.211401         B         B         9
# 1906        37.0       2011   0.161976         B         A        31
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 5870      8004         3         125.0            3        5       B
# 3686     11395         3        1406.0            3        4       A
# 9349     10311         6           NaN            1        9       B
# 8501       629         1           NaN            0        0       A
# 6632      4756        16        2857.0            5        8       B
# ...        ...       ...           ...          ...      ...     ...
# 1606      5067         4           NaN            2        6       B
# 9307       475         0           NaN            0        0       B
# 1776     14892         4           NaN            1        4       B
# 7644      1892         0           NaN            0        1       B
# 1906      7010         5        4508.0            3        7       B
#
#               Price
# 5870   79913.267856
# 3686   77835.185808
# 9349   74222.110465
# 8501  180750.471749
# 6632   88871.750230
# ...             ...
# 1606  338644.075979
# 9307  345665.209100
# 1776  528560.506016
# 7644  302211.260887
# 1906  455264.882666
#
# [10000 rows x 20 columns]

# %%
train_df['ShareLifeSquare'] = train_df['LifeSquare']/train_df['Square']
ShareLifeSquare_median = train_df['ShareLifeSquare'].median()
#ShareLifeSquare_median

train_df.loc[train_df['ShareLifeSquare'] > 0.8,'LifeSquare'] = train_df['Square'] * ShareLifeSquare_median
train_df.loc[train_df['ShareLifeSquare'] < 0.4,'LifeSquare'] = train_df['Square'] * ShareLifeSquare_median
train_df.sort_values(by='ShareLifeSquare')
#train_df['ShareLifeSquare'].value_counts()
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1388   3243         96    1.0  43.565368   17.457740            7.0    7.0
# 3511  15455        127    1.0  40.440212   16.238192           10.0    2.0
# 2453     59         27    1.0  27.181473   10.924281            8.0   10.0
# 8495  11008          0    1.0  46.934108   18.866829           10.0   16.0
# 1695  10030         27    1.0  49.486734   19.903843            1.0   15.0
# ...     ...        ...    ...        ...         ...            ...    ...
# 3283  12568         44    3.0  59.890871   47.745584            6.0    4.0
# 1911   7077        119    3.0  59.971798   47.831067            5.0    2.0
# 561   10257        101    3.0  61.461559   49.067115            6.0    9.0
# 6385   7765        109    1.0  31.123567   24.856298            5.0    8.0
# 5225  15097         37    3.0  58.215695   46.551170            6.0    4.0
#
#       HouseFloor  HouseYear  Ecology_1  ... Social_1 Social_2  Social_3  \
# 1388        10.0       2001   0.041116  ...       53    14892         4
# 3511         5.0       1960   0.486246  ...       13     2514        19
# 2453        25.0       2014   0.072158  ...        2      629         1
# 8495        17.0       2010   0.006076  ...       30     5285         0
# 1695        17.0       2016   0.017647  ...        2      469         0
# ...          ...        ...        ...  ...      ...      ...       ...
# 3283         9.0       1973   0.036122  ...       24     4378         0
# 1911         5.0       1966   0.000995  ...       42     7651         1
# 561         10.0       1971   0.038693  ...       28     6533         1
# 6385         9.0       1965   0.136330  ...       30     6141        10
# 5225         9.0       1981   0.127812  ...       28     7287         5
#
#       Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price RoomsSquare  \
# 1388           0.0            1        4        B  161933.516397   17.457740
# 3511           0.0            0        6        B  158287.271791   16.238192
# 2453           0.0            0        0        A   75170.813107   10.924281
# 8495         645.0            6        6        B   85770.442001   18.866829
# 1695           0.0            0        0        B  140042.607407   19.903843
# ...            ...          ...      ...      ...            ...         ...
# 3283        1036.0            1        1        B  245985.050425   15.915195
# 1911           0.0            1        5        B  197863.708789   15.943689
# 561         1015.0            2        5        B  281911.677971   16.355705
# 6385         262.0            3        6        B  184873.032487   24.856298
# 5225         320.0            1        3        B  217602.699683   15.517057
#
#       ShareLifeSquare
# 1388         0.400725
# 3511         0.401536
# 2453         0.401902
# 8495         0.401985
# 1695         0.402206
# ...               ...
# 3283         0.797210
# 1911         0.797559
# 561          0.798338
# 6385         0.798633
# 5225         0.799633
#
# [10000 rows x 22 columns]

# %%
train_df.loc[train_df['Rooms'] == 0, 'Rooms'] = 1
train_df['RoomsSquare'] = train_df['LifeSquare']/train_df['Rooms']
RoomsSquare_median = train_df['RoomsSquare'].median()
train_df.loc[train_df['RoomsSquare'] < 8.0, 'Rooms'] = round(train_df['LifeSquare']/RoomsSquare_median)
train_df.sort_values(by='Rooms')
#RoomsSquare_median
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9999   7202         94    1.0   35.815476   22.301367            6.0    9.0
# 4404   4457         44    1.0   31.949528   19.590010            5.0    6.0
# 4400    806        119    1.0   34.351139   22.872676            5.0    6.0
# 4393   3778        111    1.0   39.081341   19.292260            7.0    4.0
# 4392  14481        167    1.0   34.013368   17.920059           10.0   12.0
# ...     ...        ...    ...         ...         ...            ...    ...
# 1909    238         88    5.0   90.762276   70.991790            5.0    1.0
# 5737   3294        167    5.0  111.045799   81.940459            9.0    6.0
# 9515   4214        105    5.0   85.313605   56.686693            5.0    4.0
# 6290   4070         21    5.0  114.313752   88.492650            9.0    5.0
# 1906   5548         86    5.0  275.645284  179.691909           26.0   12.0
#
#       HouseFloor  HouseYear  Ecology_1  ... Social_1 Social_2  Social_3  \
# 9999         9.0       1975   0.127376  ...       43     8429         3
# 4404         9.0       1973   0.122190  ...       25     4724         2
# 4400         9.0       1966   0.000995  ...       42     7651         1
# 4393        16.0       1981   0.093443  ...       23     4635         5
# 4392        13.0       1968   0.174739  ...       17     3379         9
# ...          ...        ...        ...  ...      ...      ...       ...
# 1909         9.0       1972   0.127376  ...       43     8429         3
# 5737         6.0       1940   0.050272  ...       21     4231        14
# 9515        12.0       1967   0.040243  ...       25     3478        11
# 6290         6.0       1960   0.034331  ...       25     5487         3
# 1906        37.0       2011   0.161976  ...       31     7010         5
#
#       Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price RoomsSquare  \
# 9999           0.0            3        9        B  177685.627486   22.301367
# 4404        1308.0            1        3        B  162491.608550   19.590010
# 4400           0.0            1        5        B  166021.889867   22.872676
# 4393        3300.0            2        4        B  213835.760050   19.292260
# 4392         100.0            0        3        B  220414.158567   17.920059
# ...            ...          ...      ...      ...            ...         ...
# 1909           0.0            3        9        B  289683.939174   14.198358
# 5737        1020.0            0        3        B  513239.499082   16.388092
# 9515        2729.0            3        1        B  461678.738428   11.337339
# 6290           0.0            0        4        B  499830.937577   17.698530
# 1906        4508.0            3        7        B  455264.882666   35.938382
#
#       ShareLifeSquare
# 9999         0.622674
# 4404         0.613155
# 4400         0.665849
# 4393         0.493644
# 4392         0.526853
# ...               ...
# 1909         0.782173
# 5737         0.737898
# 9515         0.664451
# 6290         0.774121
# 1906         0.651895
#
# [10000 rows x 22 columns]

# %%
train_df['Healthcare_1'].value_counts()
# Out:
# 540.0     511
# 30.0      348
# 1046.0    245
# 750.0     163
# 229.0     148
#          ...
# 370.0      14
# 32.0       12
# 1815.0     10
# 35.0        2
# 0.0         1
# Name: Healthcare_1, Length: 79, dtype: int64

# %%
# заполним пропуски нулями
m = train_df['Healthcare_1'].isna()
train_df.loc[m,'Healthcare_1'] = 0
train_df['Healthcare_1'].value_counts()
# Out:
# 0.0       4799
# 540.0      511
# 30.0       348
# 1046.0     245
# 750.0      163
#           ...
# 1786.0      15
# 370.0       14
# 32.0        12
# 1815.0      10
# 35.0         2
# Name: Healthcare_1, Length: 79, dtype: int64

# %%
train_df.sort_values(by='KitchenSquare', ascending=False).head(40)
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9520  14656         62    1.0   47.100719   46.447960         2014.0      4
# 6505  14679         81    1.0   32.276663   19.278394         1970.0      6
# 286    2737         27    3.0  123.430072  123.430072          123.0      5
# 7733  12552         58    3.0  116.405693  113.109653          112.0      3
# 5002   7441         62    3.0  114.734473  112.589083          112.0      3
# 2454  12390         72    3.0   97.490674   97.490674           96.0     22
# 2785   6569         27    1.0   38.220258   18.716856           84.0      4
# 2831  12507         54    2.0   79.810535   79.578961           78.0     10
# 3956   4966         96    3.0   78.445675   47.146757           75.0      9
# 5273  13703         42    1.0   38.071692   19.723548           73.0      9
# 1728  16395          2    3.0   79.722243   44.731219           72.0     12
# 3240   2371         27    2.0   68.841073   64.234956           66.0      4
# 5792   6508         23    2.0   67.146049   33.959154           63.0      5
# 682   16593         52    2.0   64.859242   64.859242           62.0     15
# 3725    299         27    2.0   66.787523   64.616662           60.0     14
# 5663  11739         27    2.0   61.070298   59.845092           58.0      8
# 7601  12666         34    2.0   60.603363    2.400832           58.0     14
# 8329   7162         34    2.0   56.738764   56.738764           54.0     26
# 7080   4265        161    2.0   53.216778   32.644859           53.0      7
# 6293    673         27    1.0   54.418214   51.498581           51.0     10
# 3586  12918         23    2.0   51.440463   51.440463           51.0      3
# 2702   1315          6    1.0   48.128114   45.023531           48.0     21
# 1614   3267         58    3.0  138.980817  138.004600           43.0      2
# 456   10546         62    1.0   46.013187   43.417043           43.0      4
# 2325   7111         27    2.0  139.070296   89.787666           42.0      5
# 4091  15466         88    1.0   42.357487   42.357487           41.0     10
# 6079    448         48    1.0   41.186904    1.626502           41.0      2
# 2108   2271         27    1.0   43.292516   42.835643           40.0     12
# 3228   6708         48    1.0   42.069359   22.487739           39.0      1
# 5695  11624         46    1.0   42.983283   24.224435           37.0     15
# 8855   9690         27    1.0   40.081042   37.834964           37.0     18
# 5033  16781         27    1.0   36.138409   36.138409           36.0     19
# 755   15781         10    1.0   35.813564   19.953992           35.0      6
# 2632    300         31    2.0  106.427686   34.230415           32.0      4
# 8011   3233        129    4.0  186.692602   87.487080           32.0      3
# 2790  15947        129    4.0  185.906396   84.830074           31.0      5
# 5764   6674         54    1.0  168.086347  125.486563           30.0     18
# 511    8685         62    5.0  124.933289   81.122369           30.0      5
# 3125   8500         31    1.0   80.606246   25.299592           29.0      6
# 5746  12074         94    3.0  108.957285   51.063721           27.0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9520         1.0       2014   0.072158         B         B         2
# 6505         1.0       1977   0.006076         B         B        30
# 286         10.0       2015   0.017647         B         B         2
# 7733         3.0       2016   0.437885         B         B        23
# 5002         3.0       2015   0.072158         B         B         2
# 2454        25.0       2019   0.210473         B         B        11
# 2785        17.0       2018   0.011654         B         B         4
# 2831        15.0       2014   0.006076         B         B        30
# 3956        12.0       1977   0.041116         B         B        53
# 5273        10.0       2006   0.158249         B         B        21
# 1728        16.0       1987   0.130618         B         B        39
# 3240         2.0       2014   0.017647         B         B         2
# 5792        17.0       2019   0.034656         B         B         0
# 682         17.0       1977   0.371149         B         B        34
# 3725        20.0       2015   0.017647         B         B         2
# 5663        17.0       2016   0.072158         B         B         2
# 7601        22.0       1977   0.069753         B         B        53
# 8329        25.0       2016   0.069753         B         B        53
# 7080        17.0       1994   0.000699         B         B        14
# 6293        17.0       2017   0.072158         B         B         2
# 3586        17.0       2017   0.005767         B         B         1
# 2702         1.0       2013   0.243205         B         B         5
# 1614         2.0       1977   0.437885         B         B        23
# 456         17.0       2019   0.072158         B         B         2
# 2325         3.0       2016   0.014073         B         B         2
# 4091        19.0       2016   0.127376         B         B        43
# 6079         1.0       1977   0.041125         B         B        46
# 2108        11.0       2015   0.211401         B         B         9
# 3228        10.0       2010   0.041125         B         B        46
# 5695        16.0       1983   0.188784         B         B        31
# 8855        19.0       2019   0.211401         B         B         9
# 5033        19.0       2017   0.072158         B         B         2
# 755         14.0       1971   0.282798         B         B        33
# 2632        40.0       2013   0.151346         B         A        32
# 8011         3.0       2011   0.020741         B         B        24
# 2790         3.0       2015   0.020741         B         B        24
# 5764        28.0       2011   0.006076         B         B        30
# 511          3.0       2017   0.072158         B         B         2
# 3125        40.0       2014   0.151346         B         A        32
# 5746        22.0       2008   0.282798         B         B        33
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9520       629         1           0.0            0        0       A
# 6505      5285         0         645.0            6        6       B
# 286        469         0           0.0            0        0       B
# 7733      5735         3        1084.0            0        5       B
# 5002       629         1           0.0            0        0       A
# 2454      2398         2        1994.0            3        0       B
# 2785       915         0           0.0            0        0       B
# 2831      5285         0         645.0            6        6       B
# 3956     14892         4           0.0            1        4       B
# 5273      5731         0           0.0            1        0       B
# 1728     10418         9         900.0            1        9       B
# 3240       469         0           0.0            0        0       B
# 5792       168         0           0.0            0        0       B
# 682       7065         1         750.0            2        5       B
# 3725       469         0           0.0            0        0       B
# 5663       629         1           0.0            0        0       A
# 7601     13670         4           0.0            1       11       B
# 8329     13670         4           0.0            1       11       B
# 7080      3369        24        4129.0            0        3       B
# 6293       629         1           0.0            0        0       A
# 3586       388         0           0.0            0        0       B
# 2702      1564         0         540.0            0        0       B
# 1614      5735         3        1084.0            0        5       B
# 456        629         1           0.0            0        0       A
# 2325       475         0           0.0            0        0       B
# 4091      8429         3           0.0            3        9       B
# 6079      9515         5           0.0            1       10       B
# 2108      1892         0           0.0            0        1       B
# 3228      9515         5           0.0            1       10       B
# 5695      6137         4           0.0            0        1       B
# 8855      1892         0           0.0            0        1       B
# 5033       629         1           0.0            0        0       A
# 755       8667         2           0.0            0        6       B
# 2632      5889        10         830.0            4        1       B
# 8011      5613         5        1340.0            2        5       B
# 2790      5613         5        1340.0            2        5       B
# 5764      5285         0         645.0            6        6       B
# 511        629         1           0.0            0        0       A
# 3125      5889        10         830.0            4        1       B
# 5746      8667         2           0.0            0        6       B
#
#               Price
# 9520  108337.484207
# 6505  105539.556275
# 286   234194.837047
# 7733  296165.936689
# 5002  315245.521059
# 2454  445074.956552
# 2785   99079.960518
# 2831  438708.707579
# 3956  290354.484070
# 5273  160488.033165
# 1728  370148.625285
# 3240  189244.249909
# 5792  193130.585871
# 682   185993.474671
# 3725  179466.094235
# 5663  212188.959537
# 7601  261733.472106
# 8329  244220.621495
# 7080  261125.669724
# 6293  133273.635012
# 3586   88150.012510
# 2702  146950.912410
# 1614  169528.896664
# 456   113909.099428
# 2325  153946.777452
# 4091  194525.103119
# 6079  216882.265408
# 2108  117296.173704
# 3228  200021.835127
# 5695  198450.736353
# 8855   93218.650461
# 5033  131742.536281
# 755   164306.314182
# 2632  624549.354546
# 8011  423443.464367
# 2790  340273.238253
# 5764  367353.574566
# 511   271919.866048
# 3125  460492.010947
# 5746  562559.600217

# %%
KitchenSquare_median = train_df['KitchenSquare'].median()
KitchenSquare_median
# Out:
# 6.0

# %%
# все значения площади кухни больше 32 введены ошибочно, прировняем к медиане
m = train_df['KitchenSquare'] > 32
train_df.loc[m,'KitchenSquare'] = KitchenSquare_median
train_df.sort_values(by='KitchenSquare')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 4990   1177         23    1.0   30.806585   27.776211            0.0      2
# 7576    572         46    3.0   75.495643   75.495643            0.0      7
# 672   12687         27    2.0   65.444497   65.444497            0.0      7
# 9099  12455         27    2.0   61.572459   61.572459            0.0      8
# 5617   5983          1    1.0   40.441276   40.441276            0.0      4
# ...     ...        ...    ...         ...         ...            ...    ...
# 5764   6674         54    1.0  168.086347  125.486563           30.0     18
# 511    8685         62    5.0  124.933289   81.122369           30.0      5
# 2790  15947        129    4.0  185.906396   84.830074           31.0      5
# 2632    300         31    2.0  106.427686   34.230415           32.0      4
# 8011   3233        129    4.0  186.692602   87.487080           32.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4990         0.0       1977   0.034656         B         B         0
# 7576         0.0       1977   0.000000         B         B        47
# 672         19.0       1977   0.211401         B         B         9
# 9099        19.0       1977   0.211401         B         B         9
# 5617        17.0       1977   0.007122         B         B         1
# ...          ...        ...        ...       ...       ...       ...
# 5764        28.0       2011   0.006076         B         B        30
# 511          3.0       2017   0.072158         B         B         2
# 2790         3.0       2015   0.020741         B         B        24
# 2632        40.0       2013   0.151346         B         A        32
# 8011         3.0       2011   0.020741         B         B        24
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 4990       168         0           0.0            0        0       B
# 7576     11319         0        1145.0            3        5       B
# 672       1892         0           0.0            0        1       B
# 9099      1892         0           0.0            0        1       B
# 5617       264         0           0.0            0        1       B
# ...        ...       ...           ...          ...      ...     ...
# 5764      5285         0         645.0            6        6       B
# 511        629         1           0.0            0        0       A
# 2790      5613         5        1340.0            2        5       B
# 2632      5889        10         830.0            4        1       B
# 8011      5613         5        1340.0            2        5       B
#
#               Price
# 4990   65379.957345
# 7576  422792.116135
# 672   146247.605596
# 9099  136045.775200
# 5617  161216.973771
# ...             ...
# 5764  367353.574566
# 511   271919.866048
# 2790  340273.238253
# 2632  624549.354546
# 8011  423443.464367
#
# [10000 rows x 20 columns]

# %%
# этажность дома равную нулю прировняем к 1
m = train_df['HouseFloor'] == 0
train_df.loc[m,'HouseFloor'] = 1
train_df.sort_values(by='HouseFloor')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7709   5142         27    3.0   87.916106   87.916106           10.0      2
# 4724    376         25    2.0   62.265170   58.985551            1.0     20
# 3318   4102         27    3.0   86.100429   86.100429            1.0      7
# 1279  10406         24    2.0   54.551991   54.551991            1.0     22
# 7854  14162         23    2.0   57.410794   57.410794            1.0      4
# ...     ...        ...    ...         ...         ...            ...    ...
# 5031   7453         24    3.0  126.621358   62.455481           12.0     22
# 4987   1674         76    2.0   74.344672   41.044132            5.0     42
# 746    9300         74    2.0   71.747869   71.747869            9.0      5
# 4657  10806          5    1.0   51.944587   48.709601            1.0      6
# 1678     78         30    2.0   65.773749   65.773749            1.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7709         1.0       1977   0.072158         B         B         2
# 4724         1.0       2018   0.069753         B         B        53
# 3318         1.0       2015   0.017647         B         B         2
# 1279         1.0       1977   0.111627         B         B        50
# 7854         1.0       1977   0.034656         B         B         0
# ...          ...        ...        ...       ...       ...       ...
# 5031        48.0       2011   0.111627         B         B        50
# 4987        48.0       2016   0.000000         B         B         7
# 746         99.0       1977   0.075779         B         B         6
# 4657        99.0       1977   0.150818         B         B        16
# 1678       117.0       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 7709       629         1           0.0            0        0       A
# 4724     13670         4           0.0            1       11       B
# 3318       469         0           0.0            0        0       B
# 1279     12238         8        1970.0            2        3       B
# 7854       168         0           0.0            0        0       B
# ...        ...       ...           ...          ...      ...     ...
# 5031     12238         8        1970.0            2        3       B
# 4987      1660        39        1786.0            1        5       B
# 746       1437         3           0.0            0        2       B
# 4657      3433         4        2643.0            4        5       B
# 1678      6398       141        1046.0            3       23       B
#
#               Price
# 7709  243750.128072
# 4724  284467.144257
# 3318  240645.013469
# 1279  322544.371625
# 7854  114907.789623
# ...             ...
# 5031  179396.521035
# 4987  411691.504766
# 746   243329.912579
# 4657  296127.115515
# 1678  207248.370520
#
# [10000 rows x 20 columns]

# %%
HouseFloor_median = train_df['HouseFloor'].median()
HouseFloor_median
# Out:
# 13.0

# %%
# все значения этажности здания больше 76 введены ошибочно, прировняем к медиане
m = train_df['HouseFloor'] > 76
train_df.loc[m,'HouseFloor'] = HouseFloor_median
train_df.sort_values(by='HouseFloor')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7709   5142         27    3.0   87.916106   87.916106           10.0      2
# 4724    376         25    2.0   62.265170   58.985551            1.0     20
# 3318   4102         27    3.0   86.100429   86.100429            1.0      7
# 1279  10406         24    2.0   54.551991   54.551991            1.0     22
# 7854  14162         23    2.0   57.410794   57.410794            1.0      4
# ...     ...        ...    ...         ...         ...            ...    ...
# 765    6589         30    1.0   62.110823   52.812128            4.0     31
# 646    5279         93    2.0   60.804544   30.923827           11.0      5
# 5259   6502         20    1.0  126.389517  103.637322           14.0     22
# 4987   1674         76    2.0   74.344672   41.044132            5.0     42
# 5031   7453         24    3.0  126.621358   62.455481           12.0     22
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7709         1.0       1977   0.072158         B         B         2
# 4724         1.0       2018   0.069753         B         B        53
# 3318         1.0       2015   0.017647         B         B         2
# 1279         1.0       1977   0.111627         B         B        50
# 7854         1.0       1977   0.034656         B         B         0
# ...          ...        ...        ...       ...       ...       ...
# 765         44.0       2009   0.000078         B         B        22
# 646         45.0       2016   0.050900         B         B        43
# 5259        47.0       2012   0.019509         B         B        37
# 4987        48.0       2016   0.000000         B         B         7
# 5031        48.0       2011   0.111627         B         B        50
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 7709       629         1           0.0            0        0       A
# 4724     13670         4           0.0            1       11       B
# 3318       469         0           0.0            0        0       B
# 1279     12238         8        1970.0            2        3       B
# 7854       168         0           0.0            0        0       B
# ...        ...       ...           ...          ...      ...     ...
# 765       6398       141        1046.0            3       23       B
# 646      10621         1          30.0            2        3       B
# 5259      7687        11         176.0            5        5       B
# 4987      1660        39        1786.0            1        5       B
# 5031     12238         8        1970.0            2        3       B
#
#               Price
# 7709  243750.128072
# 4724  284467.144257
# 3318  240645.013469
# 1279  322544.371625
# 7854  114907.789623
# ...             ...
# 765   117647.461002
# 646   213171.135199
# 5259  450706.552655
# 4987  411691.504766
# 5031  179396.521035
#
# [10000 rows x 20 columns]

# %%
# во всех случаях, где этажность здания меньше этажа, поменяем значения местами
m = train_df['HouseFloor'] < train_df['Floor']
train_df.loc[m,['HouseFloor', 'Floor']] = train_df.loc[m,['Floor', 'HouseFloor']].to_numpy()
train_df.sort_values(by='HouseFloor')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7092  15863         58    1.0   47.309137   47.309137            1.0    1.0
# 797    9823         27    1.0   48.455708   48.455708            0.0    1.0
# 1397  12826          1    1.0   48.060539   48.060539            1.0    1.0
# 8232   2967          1    1.0   62.494611    3.489694            0.0    1.0
# 6924   8933          9    1.0   50.567182   45.603353            1.0    1.0
# ...     ...        ...    ...         ...         ...            ...    ...
# 765    6589         30    1.0   62.110823   52.812128            4.0   31.0
# 646    5279         93    2.0   60.804544   30.923827           11.0    5.0
# 5259   6502         20    1.0  126.389517  103.637322           14.0   22.0
# 4987   1674         76    2.0   74.344672   41.044132            5.0   42.0
# 5031   7453         24    3.0  126.621358   62.455481           12.0   22.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7092         1.0       1977   0.437885         B         B        23
# 797          1.0       1977   0.011654         B         B         4
# 1397         1.0       1977   0.007122         B         B         1
# 8232         1.0       1977   0.007122         B         B         1
# 6924         1.0       1977   0.161532         B         B        25
# ...          ...        ...        ...       ...       ...       ...
# 765         44.0       2009   0.000078         B         B        22
# 646         45.0       2016   0.050900         B         B        43
# 5259        47.0       2012   0.019509         B         B        37
# 4987        48.0       2016   0.000000         B         B         7
# 5031        48.0       2011   0.111627         B         B        50
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 7092      5735         3        1084.0            0        5       B
# 797        915         0           0.0            0        0       B
# 1397       264         0           0.0            0        1       B
# 8232       264         0           0.0            0        1       B
# 6924      5648         1          30.0            2        4       B
# ...        ...       ...           ...          ...      ...     ...
# 765       6398       141        1046.0            3       23       B
# 646      10621         1          30.0            2        3       B
# 5259      7687        11         176.0            5        5       B
# 4987      1660        39        1786.0            1        5       B
# 5031     12238         8        1970.0            2        3       B
#
#               Price
# 7092  114949.106711
# 797   114606.936746
# 1397  124591.333737
# 8232  193568.854208
# 6924  144534.046032
# ...             ...
# 765   117647.461002
# 646   213171.135199
# 5259  450706.552655
# 4987  411691.504766
# 5031  179396.521035
#
# [10000 rows x 20 columns]

# %%
HouseYear_median = train_df['HouseYear'].median()
HouseYear_median
# Out:
# 1977.0

# %%
# все значения года постройки больше текущего введены ошибочно, прировняем к медиане
m = train_df['HouseYear'] > datetime.datetime.now().year
train_df.loc[m,'HouseYear'] = HouseYear_median
train_df.sort_values(by='HouseYear')
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 6794  13288        161    1.0   50.808925   15.920343           20.0    8.0
# 2066  14556        183    4.0  151.150660   98.187482           23.0    6.0
# 2795   2085        161    1.0   63.293079   29.389815           18.0    3.0
# 6250   6751        172    2.0   56.172364   28.384213            7.0    6.0
# 7610   7920        183    3.0  102.964468   48.322107           14.0    4.0
# ...     ...        ...    ...         ...         ...            ...    ...
# 7207   3445         53    1.0   35.672788   21.391266            8.0    4.0
# 6073   6845        169    3.0   87.371123   64.905206           12.0    4.0
# 8296   8832          1    3.0   83.260743   79.438325            1.0   15.0
# 2350  14318         53    2.0   57.815313   37.287063            8.0    6.0
# 1976  13914         23    3.0   74.222388   44.992259           13.0    3.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6794         9.0       1910   0.014423         B         B        19
# 2066         7.0       1912   0.037316         B         B        32
# 2795         9.0       1912   0.014423         B         B        19
# 6250         8.0       1914   0.000000         B         B         7
# 7610         6.0       1916   0.037316         B         B        32
# ...          ...        ...        ...       ...       ...       ...
# 7207        24.0       2020   0.049637         B         B        34
# 6073        24.0       2020   0.178917         B         B        18
# 8296        21.0       2020   0.007122         B         B         1
# 2350        24.0       2020   0.049637         B         B        34
# 1976         5.0       2020   0.005767         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6794      3806         4           0.0            0        3       B
# 2066      6748        93         562.0            4       10       B
# 2795      3806         4           0.0            0        3       B
# 6250      1660        39        1786.0            1        5       B
# 7610      6748        93         562.0            4       10       B
# ...        ...       ...           ...          ...      ...     ...
# 7207      7759         0         229.0            1        3       B
# 6073      3594         4         192.0            1        5       B
# 8296       264         0           0.0            0        1       B
# 2350      7759         0         229.0            1        3       B
# 1976       388         0           0.0            0        0       B
#
#               Price
# 6794  287954.720682
# 2066  284884.959104
# 2795  262279.813915
# 6250  423580.477982
# 7610  284608.939261
# ...             ...
# 7207  170847.416766
# 6073  295304.011974
# 8296  242243.090839
# 2350  251249.365740
# 1976  106209.372321
#
# [10000 rows x 20 columns]

# %%
class DataPreprocessing:
    """Подготовка исходных данных"""

    def __init__(self):
        """Параметры класса"""
        self.medians = None
        
    def fit(self, X):
        """Сохранение статистик"""       
        # Расчет медиан
        self.medians = X.median()
    
    def transform(self, X):
        """Трансформация данных"""

        # Id, DistrictId
        X['Id'] = X['Id'].astype(str)
        X['DistrictId'] = X['DistrictId'].astype(str)
        
        # Square, LifeSquare
        
        # если жилая плащадь больше общей, то приравниваем её к общей
        X.loc[X['Square'] < X['LifeSquare'],'LifeSquare'] = X.loc[X['Square'] < X['LifeSquare'],'Square'] 
        
        # заполняем пропуски в значениях жилой площади значениями общей площади
        X.loc[X['LifeSquare'].isna(),'LifeSquare'] = X.loc[X['LifeSquare'].isna(),'Square'] 
        
        # если общая площадь менее 15, заменяем на медиану
        X.loc[X['Square'] < 15,'Square'] = self.medians['Square'] 
        
        # общая площадь более 300 - неверно поставленная запятая, делим на 10
        X.loc[X['Square'] > 300,'Square'] = X.loc[X['Square'] > 300,'Square']/10
        
        # определяем процент жилой площади, если он < или > нормативов, считаем жилую площадь через медиану коэффициента
        X['ShareLifeSquare'] = X['LifeSquare']/X['Square']
        ShareLifeSquare_median = X['ShareLifeSquare'].median()
        X.loc[X['ShareLifeSquare'] > 0.8,'LifeSquare'] = X['Square'] * ShareLifeSquare_median
        X.loc[X['ShareLifeSquare'] < 0.4,'LifeSquare'] = X['Square'] * ShareLifeSquare_median
        X.drop(columns='ShareLifeSquare')
        
        
        # Rooms
        
        # количество комнат равное нулю приравниваем к 1
        X.loc[X['Rooms'] == 0, 'Rooms'] = 1
        
        # вычисляем среднюю площадь комнаты и медиану этих значений
        X['RoomsSquare'] = X['LifeSquare']/X['Rooms']
        RoomsSquare_median = X['RoomsSquare'].median()
        
        # если средняя площадь комнаты меньше нормативов, пересчитываем количество комнат по нормативам 
        X.loc[X['RoomsSquare'] < 8.0, 'Rooms'] = round(X['LifeSquare']/RoomsSquare_median)
        X.drop(columns='RoomsSquare')
        
        # KitchenSquare
        
        # площадь кухни меньше 3 приравниваем к 3
        X.loc[X['KitchenSquare'] < 3, 'KitchenSquare'] = 3
        
        # все значения площади кухни больше 32 введены ошибочно, прировняем к медиане
        X.loc[X['KitchenSquare'] > 32,'KitchenSquare'] = self.medians['KitchenSquare']
        
        
        # HouseFloor, Floor
        
        # этажность дома равную нулю прировняем к 1
        X.loc[X['HouseFloor'] == 0,'HouseFloor'] = 1
        
        # все значения этажности здания больше 76 введены ошибочно, прировняем к медиане
        X.loc[X['HouseFloor'] > 76,'HouseFloor'] = self.medians['HouseFloor']
        
        # во всех случаях, где этажность здания меньше этажа, поменяем значения местами
        X.loc[X['HouseFloor'] < X['Floor'],['HouseFloor', 'Floor']] = X.loc[X['HouseFloor'] < X['Floor'],['Floor', 'HouseFloor']].to_numpy()

        
        # HouseYear
        
        # все значения года постройки больше текущего введены ошибочно, прировняем к медиане
        current_year = datetime.datetime.now().year
        
        X.loc[X['HouseYear'] > current_year, 'HouseYear'] = current_year
        
        # Healthcare_1
        
        # заполним пропуски нулями
        X.loc[X['Healthcare_1'].isna(),'Healthcare_1'] = 0
                
        
        X.fillna(self.medians, inplace=True)
        
        return X

# %%
class FeatureGenetator():
    """Генерация новых фич"""
    
    def __init__(self):
        self.DistrictId_counts = None
        self.binary_to_numbers = None
        self.med_price_by_district = None
        self.med_price_by_floor_year = None
        self.house_year_max = None
        self.floor_max = None
        self.house_year_min = None
        self.floor_min = None
        self.district_size = None
        self.ShareLifeSquare = None
        self.RoomsSquare = None
        
        
    def fit(self, X, y=None):
        
        X = X.copy()
        
        # Binary features
        self.binary_to_numbers = {'A': 0, 'B': 1}
        
        # DistrictID
        self.district_size = X['DistrictId'].value_counts().reset_index() \
                               .rename(columns={'index':'DistrictId', 'DistrictId':'DistrictSize'})
                
        # Target encoding
        ## District, Rooms
        df = X.copy()
        
        if y is not None:
            df['Price'] = y.values
            
            self.med_price_by_district = df.groupby(['DistrictId', 'Rooms'], as_index=False).agg({'Price':'median'})\
                                            .rename(columns={'Price':'MedPriceByDistrict'})
            
            self.med_price_by_district_median = self.med_price_by_district['MedPriceByDistrict'].median()
            
        ## floor, year
        if y is not None:
            self.floor_max = df['Floor'].max()
            self.floor_min = df['Floor'].min()
            self.house_year_max = df['HouseYear'].max()
            self.house_year_min = df['HouseYear'].min()
            df['Price'] = y.values
            df = self.floor_to_cat(df)
            df = self.year_to_cat(df)
            self.med_price_by_floor_year = df.groupby(['year_cat', 'floor_cat'], as_index=False).agg({'Price':'median'}).\
                                            rename(columns={'Price':'MedPriceByFloorYear'})
            self.med_price_by_floor_year_median = self.med_price_by_floor_year['MedPriceByFloorYear'].median()
        

        
    def transform(self, X):
        
        # Binary features
        X['Ecology_2'] = X['Ecology_2'].map(self.binary_to_numbers)  # self.binary_to_numbers = {'A': 0, 'B': 1}
        X['Ecology_3'] = X['Ecology_3'].map(self.binary_to_numbers)
        X['Shops_2'] = X['Shops_2'].map(self.binary_to_numbers)
        
        # DistrictId, IsDistrictLarge
        X = X.merge(self.district_size, on='DistrictId', how='left')
        
        X['new_district'] = 0
        X.loc[X['DistrictSize'].isna(), 'new_district'] = 1
        
        X['DistrictSize'].fillna(5, inplace=True)
        
        X['IsDistrictLarge'] = (X['DistrictSize'] > 100).astype(int)
        
        # More categorical features
        X = self.floor_to_cat(X)  # + столбец floor_cat
        X = self.year_to_cat(X)   # + столбец year_cat
        
        # Target encoding
        if self.med_price_by_district is not None:
            X = X.merge(self.med_price_by_district, on=['DistrictId', 'Rooms'], how='left')
            X['MedPriceByDistrict'].fillna(self.med_price_by_district_median, inplace=True)
            
        if self.med_price_by_floor_year is not None:
            X = X.merge(self.med_price_by_floor_year, on=['year_cat', 'floor_cat'], how='left')
            X['MedPriceByFloorYear'].fillna(self.med_price_by_floor_year_median, inplace=True)
        
        # ShareLifeSquare
        X['ShareLifeSquare'] = X['LifeSquare']/X['Square']
        
        # RoomsSquare
        X['RoomsSquare'] = X['LifeSquare']/X['Rooms']
        
        
        return X
    
    def floor_to_cat(self, X):
        bins = [self.floor_min, 3, 5, 9, 15, self.floor_max]
        X['floor_cat'] = pd.cut(X['Floor'], bins=bins, labels=False)

        X['floor_cat'].fillna(-1, inplace=True)
        return X
     
    def year_to_cat(self, X):
        bins = [self.house_year_min, 1941, 1945, 1980, 2000, 2010, self.house_year_max]
        X['year_cat'] = pd.cut(X['HouseYear'], bins=bins, labels=False)

        X['year_cat'].fillna(-1, inplace=True)
        return X

# %%
train_df.columns.tolist()
# Out:
# ['Id',
#  'DistrictId',
#  'Rooms',
#  'Square',
#  'LifeSquare',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Ecology_2',
#  'Ecology_3',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Healthcare_1',
#  'Helthcare_2',
#  'Shops_1',
#  'Shops_2',
#  'Price',
#  'RoomsSquare',
#  'ShareLifeSquare']

# %%
feature_names = ['Id', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare', 'Floor', 'HouseFloor', 'HouseYear',
                 'Ecology_1', 'Ecology_2', 'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
                 'Helthcare_2', 'Shops_1', 'Shops_2']

new_feature_names = ['DistrictSize', 'new_district', 'IsDistrictLarge', 'MedPriceByFloorYear', 
                     'RoomsSquare', 'ShareLifeSquare']

target_name = 'Price'

# %%
train_df = pd.read_csv(TRAIN_DATASET_PATH)
test_df = pd.read_csv(TEST_DATASET_PATH)

X = train_df.drop(columns=target_name)
y = train_df[target_name]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=21)

# %%
preprocessor = DataPreprocessing()
preprocessor.fit(X_train)

X_train = preprocessor.transform(X_train)
X_valid = preprocessor.transform(X_valid)
test_df = preprocessor.transform(test_df)

X_train.shape, X_valid.shape, test_df.shape
# Out:
# ((6700, 21), (3300, 21), (5000, 21))

# %%
test_df.columns.tolist()
# Out:
# ['Id',
#  'DistrictId',
#  'Rooms',
#  'Square',
#  'LifeSquare',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Ecology_2',
#  'Ecology_3',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Healthcare_1',
#  'Helthcare_2',
#  'Shops_1',
#  'Shops_2',
#  'ShareLifeSquare',
#  'RoomsSquare']

# %%
features_gen = FeatureGenetator()
features_gen.fit(X_train, y_train)

X_train = features_gen.transform(X_train)
X_valid = features_gen.transform(X_valid)
test_df = features_gen.transform(test_df)

X_train.shape, X_valid.shape, test_df.shape
# Out:
# ((6700, 28), (3300, 28), (5000, 28))

# %%
test_df.columns.tolist()
# Out:
# ['Id',
#  'DistrictId',
#  'Rooms',
#  'Square',
#  'LifeSquare',
#  'KitchenSquare',
#  'Floor',
#  'HouseFloor',
#  'HouseYear',
#  'Ecology_1',
#  'Ecology_2',
#  'Ecology_3',
#  'Social_1',
#  'Social_2',
#  'Social_3',
#  'Healthcare_1',
#  'Helthcare_2',
#  'Shops_1',
#  'Shops_2',
#  'ShareLifeSquare',
#  'RoomsSquare',
#  'DistrictSize',
#  'new_district',
#  'IsDistrictLarge',
#  'floor_cat',
#  'year_cat',
#  'MedPriceByDistrict',
#  'MedPriceByFloorYear']

# %%
X_train = X_train[feature_names + new_feature_names]
X_valid = X_valid[feature_names + new_feature_names]
test_df = test_df[feature_names + new_feature_names]

# %%
#X_train.isna().sum().sum(), X_valid.isna().sum().sum(), test_df.isna().sum().sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# Работа с моделью

# %%
rf_model = RandomForestRegressor(random_state=21, criterion='mse')
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=21)

# %%
y_train_preds = rf_model.predict(X_train)
y_test_preds = rf_model.predict(X_valid)

evaluate_preds(y_train, y_train_preds, y_valid, y_test_preds)
# Out:
# Train R2:	0.961
# Test R2:	0.746

# %%
cv_score = cross_val_score(rf_model, X_train, y_train, scoring='r2', cv=KFold(n_splits=3, shuffle=True, random_state=21))
cv_score
# Out:
# array([0.72971749, 0.68169884, 0.71905631])

# %%
feature_importances = pd.DataFrame(zip(X_train.columns, rf_model.feature_importances_), 
                                   columns=['feature_name', 'importance'])

feature_importances.sort_values(by='importance', ascending=False)
# Out:
#            feature_name  importance
# 2                Square    0.401843
# 18         DistrictSize    0.214054
# 13             Social_3    0.051269
# 8             Ecology_1    0.029679
# 12             Social_2    0.029348
# 1                 Rooms    0.027929
# 21  MedPriceByFloorYear    0.025961
# 22          RoomsSquare    0.025887
# 7             HouseYear    0.023485
# 3            LifeSquare    0.022594
# 6            HouseFloor    0.022440
# 0                    Id    0.021863
# 11             Social_1    0.021805
# 23      ShareLifeSquare    0.017494
# 5                 Floor    0.015736
# 4         KitchenSquare    0.014669
# 16              Shops_1    0.012937
# 14         Healthcare_1    0.012230
# 15          Helthcare_2    0.006387
# 17              Shops_2    0.001387
# 20      IsDistrictLarge    0.000420
# 10            Ecology_3    0.000365
# 9             Ecology_2    0.000219
# 19         new_district    0.000000

# %%
gb_model = GradientBoostingRegressor(max_depth=5, n_estimators=200, random_state=42)
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=200, random_state=42)

# %%
y_train_preds = gb_model.predict(X_train)
evaluate_preds(y_train, y_train_preds, y_valid, y_test_preds)
# Out:
# Train R2:	0.912
# Test R2:	0.749

# %%
feature_importances = pd.DataFrame(zip(X_train.columns, gb_model.feature_importances_), 
                                   columns=['feature_name', 'importance'])

feature_importances.sort_values(by='importance', ascending=False)
# Out:
#            feature_name  importance
# 1                Square    0.428290
# 17         DistrictSize    0.225837
# 12             Social_3    0.052815
# 11             Social_2    0.040085
# 0                 Rooms    0.029804
# 7             Ecology_1    0.028568
# 20  MedPriceByFloorYear    0.028325
# 5            HouseFloor    0.021509
# 2            LifeSquare    0.020322
# 6             HouseYear    0.019736
# 10             Social_1    0.018280
# 21          RoomsSquare    0.018018
# 22      ShareLifeSquare    0.015739
# 13         Healthcare_1    0.014757
# 15              Shops_1    0.011680
# 3         KitchenSquare    0.011006
# 4                 Floor    0.010048
# 14          Helthcare_2    0.003579
# 16              Shops_2    0.001052
# 9             Ecology_3    0.000256
# 8             Ecology_2    0.000209
# 19      IsDistrictLarge    0.000087
# 18         new_district    0.000000

# %% [markdown]
# Работа с тестовым датасетом

# %%
test_df.shape
# Out:
# (5000, 23)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rooms                5000 non-null   float64
#  1   Square               5000 non-null   float64
#  2   LifeSquare           5000 non-null   float64
#  3   KitchenSquare        5000 non-null   float64
#  4   Floor                5000 non-null   float64
#  5   HouseFloor           5000 non-null   float64
#  6   HouseYear            5000 non-null   int64
#  7   Ecology_1            5000 non-null   float64
#  8   Ecology_2            5000 non-null   int64
#  9   Ecology_3            5000 non-null   int64
#  10  Social_1             5000 non-null   int64
#  11  Social_2             5000 non-null   int64
#  12  Social_3             5000 non-null   int64
#  13  Healthcare_1         5000 non-null   float64
#  14  Helthcare_2          5000 non-null   int64
#  15  Shops_1              5000 non-null   int64
#  16  Shops_2              5000 non-null   int64
#  17  DistrictSize         5000 non-null   float64
#  18  new_district         5000 non-null   int64
#  19  IsDistrictLarge      5000 non-null   int32
#  20  MedPriceByFloorYear  5000 non-null   float64
#  21  RoomsSquare          5000 non-null   float64
#  22  ShareLifeSquare      5000 non-null   float64
# dtypes: float64(12), int32(1), int64(10)
# memory usage: 918.0 KB

# %%
predictions = rf_model.predict(test_df)
predictions
# Out:
# array([155781.22785015, 124006.84371236, 139039.0160795 , ...,
#        144556.48875485, 191186.20285253, 266112.82752244])

# %%
test_df['Price'] = predictions
test_df.head()
# Out:
#      Id  Rooms     Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# 0  4567    1.0  36.847630   19.094182            5.0    5.0         9.0
# 1  5925    1.0  42.493907   27.667080           10.0    7.0        17.0
# 2   960    2.0  59.463678   38.715817            9.0   19.0        19.0
# 3  3848    3.0  49.646030   33.893825            6.0    2.0         2.0
# 4   746    1.0  53.837056   35.052416            3.0    8.0        17.0
#
#    HouseYear  Ecology_1  Ecology_2  ...  Helthcare_2  Shops_1  Shops_2  \
# 0       1970   0.036122          1  ...            1        1        1
# 1       2017   0.072158          1  ...            0        0        0
# 2       1977   0.211401          1  ...            0        1        1
# 3       1965   0.014073          1  ...            0        0        1
# 4       1977   0.309479          1  ...            0        6        1
#
#    DistrictSize  new_district  IsDistrictLarge  MedPriceByFloorYear  \
# 0          76.0             0                0        186518.438291
# 1         164.0             0                1        178912.369081
# 2         580.0             0                1        175622.388268
# 3         372.0             0                1        181020.120527
# 4          65.0             0                0        193098.662333
#
#    RoomsSquare  ShareLifeSquare          Price
# 0    19.094182         0.518193  155781.227850
# 1    27.667080         0.651083  124006.843712
# 2    19.357908         0.651083  139039.016080
# 3    11.297942         0.682710  130444.516544
# 4    35.052416         0.651083  220220.220218
#
# [5 rows x 25 columns]

# %%
test_df.to_csv(PREDICTIONS_PATH, columns=['Id', 'Price'], index=False, encoding='utf-8')
